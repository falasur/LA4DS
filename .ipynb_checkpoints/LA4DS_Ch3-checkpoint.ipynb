# %% [markdown]
# # Exercises from Linear Algebra for DS

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.io as pio

pio.renderers.default='iframe'
#plt.figure(figsize=(12, 12), dpi=80)
plt.rcParams["figure.figsize"] = (7,7)

# %%
#function to create nd vectors in (0, 10, 0, 10)
def vec(dim=2):
    return np.random.rand(dim)*10

# function to create row vectors
def row(dim=2):
    return np.array([vec(dim=2)])

# %% [markdown]
# ## Chapter 3

# %% [markdown]
# ### Exercise 3.1

# %% [markdown]
# Write a function for linear combination of vectors

# %%
def lincomb(scalars, vectors):
    return sum([i*j for i, j in zip(scalars, vectors)])

# %%
a = vec()
b = vec()
c = vec()

scalars = np.random.randint(-5,5, size=3)

x = lincomb(scalars, [a,b,c])

# %%
scalars
# Out:
# array([ 2, -4, -2])

# %%
np.array([a,b,c]).T @ np.array(scalars).T, lincomb(scalars, [a,b,c])
# Out:
# (array([-45.68904799, -17.5903354 ]), array([-45.68904799, -17.5903354 ]))

# %%
a_l = a*scalars[0]
b_l = b*scalars[1]
c_l = c*scalars[2]



plt.arrow(0,0, *a_l, color = 'green', length_includes_head=True, width=0.1, head_width=0.3)
plt.arrow(*a_l, *b_l, color = 'green', length_includes_head=True, width=0.1, head_width=0.3)
plt.arrow(*(a_l+b_l), *c_l, color = 'green', length_includes_head=True, width=0.1, head_width=0.3)
plt.arrow(0,0, *x, color = 'orange', length_includes_head=True, width=0.1, head_width=0.3, ls=':')

plt.axvline(0,0, color='grey', ls='--')
plt.axhline(0,0, color='grey', ls='--')

# %% [markdown]
# ### Exercise 3.2

# %% [markdown]
# Illustrate how different spaces (R2, R3) behave

# %%
# Case for R2

lambdas = np.array([np.random.uniform(-4, 4, 100)])

x = np.array([[1,3]])

dots = x.T @ lambdas

# %%
sns.scatterplot(x=dots[0], y=dots[1])
# Out:
# <AxesSubplot:>

# %%
# R3 cases: 2 vectors 

lambdas = np.array(np.random.uniform(-4, 4, 200)).reshape((2,100))

a = np.array([3,5,1])
b = np.array([0,2,2])

points = np.array([a,b]).T @ lambdas

# %%
go.Figure(data=[go.Scatter3d(
                        x=points[0, :],
                        y=points[1, :],
                        z=points[2, :],
                        mode='markers')])

# all points belong to one plane
# Out:
# <div>                            <div id="0470ce3e-d407-4a9f-98db-abe8ecdeab33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0470ce3e-d407-4a9f-98db-abe8ecdeab33")) {                    Plotly.newPlot(                        "0470ce3e-d407-4a9f-98db-abe8ecdeab33",                        [{"mode":"markers","x":[10.554656607279412,-4.84516811686948,-1.314434990136398,-9.724527387908848,-8.268887150710317,1.2453963986596142,-2.1677734671700026,1.630437261121899,5.419281241504388,1.3223689673050751,7.0770530559427405,-1.7863167881703577,-2.7485369487285984,2.0248311412534354,7.0561478938349,0.6673886520812751,-4.9105368014737065,8.702975650796626,9.120134857219249,-2.4077893688327974,4.1286781714027105,-0.9861578858623821,-0.04075232830579001,5.277344536256957,0.8933748070088976,-5.2471348588392175,-7.546487985059436,10.284646532986404,3.8545854434008957,3.003627314324631,5.596113875461897,4.641710153250284,9.679872982091794,-9.742040550192208,7.001602422213954,-6.417455098491221,-1.9698630407117843,-10.888007991644372,4.34162738788972,-11.411946496661857,8.368707019372462,11.999852203691352,0.5880950435738477,9.319386245631485,-1.2146913906687429,-4.912899281344809,-7.348179512496143,11.205827799306533,1.3414614358390295,-9.48258153989579,4.589152523047791,-